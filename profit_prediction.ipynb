# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
data = pd.read_csv('1000_companies.csv')
data
# Out:
#      R&D Spend  Administration  Marketing Spend       State        Profit
# 0    165349.20      136897.800      471784.1000    New York  192261.83000
# 1    162597.70      151377.590      443898.5300  California  191792.06000
# 2    153441.51      101145.550      407934.5400     Florida  191050.39000
# 3    144372.41      118671.850      383199.6200    New York  182901.99000
# 4    142107.34       91391.770      366168.4200     Florida  166187.94000
# ..         ...             ...              ...         ...           ...
# 995   54135.00      118451.999      173232.6695  California   95279.96251
# 996  134970.00      130390.080      329204.0228  California  164336.60550
# 997  100275.47      241926.310      227142.8200  California  413956.48000
# 998  128456.23      321652.140      281692.3200  California  333962.19000
# 999  161181.72      270939.860      295442.1700    New York  476485.43000
#
# [1000 rows x 5 columns]

# %%
companies.corr()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_9348\2152725344.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   companies.corr()
#                  R&D Spend  Administration  Marketing Spend    Profit
# R&D Spend         1.000000        0.582434         0.978407  0.945245
# Administration    0.582434        1.000000         0.520465  0.741560
# Marketing Spend   0.978407        0.520465         1.000000  0.917270
# Profit            0.945245        0.741560         0.917270  1.000000

# %%
mkt = {
    "ad" : data['Marketing Spend'],
    "profit" : data['Profit']
}
mkt = pd.DataFrame(mkt)
mkt.plot(figsize=(20,5))
plt.title("A Graphical Representation of the correlation Between Marketing Spend and Profit")
plt.xlabel("Range")
plt.ylabel("Amount")
plt.grid()

# %%
mkt = {
    "ad" : data['Marketing Spend'][:100],
    "profit" : data['Profit'][:100]
}
mkt = pd.DataFrame(mkt)
mkt.plot(figsize=(20,5))
plt.title("The First Hundred Observations")
plt.xlabel("Range")
plt.ylabel("Amount")
plt.grid()

# %%
mkt = {
    "ad" : data['Marketing Spend'][900:],
    "profit" : data['Profit'][900:]
}
mkt = pd.DataFrame(mkt)
mkt.plot(figsize=(20,5))
plt.title("The last Hundred Observations")
plt.xlabel("Range")
plt.ylabel("Amount")
plt.grid()

# %%
rd = {
    "ad" : data['R&D Spend'],
    "profit" : data['Profit']
}
rd = pd.DataFrame(rd)
rd.plot(figsize=(20,10))
plt.title("A Graphical Representation of the correlation Between R&D Spend and Profit")
plt.xlabel("Range")
plt.ylabel("Amount")
plt.grid()

# %%
rd = {
    "ad" : data['R&D Spend'][:100],
    "profit" : data['Profit'][:100]
}
rd = pd.DataFrame(rd)
rd.plot(figsize=(20,8))
plt.title("A Graphical Representation of the correlation Between R&D Spend and Profit()")
plt.xlabel("Range")
plt.ylabel("Amount")
plt.grid()

# %%
X = {
    "mkt" : data['Marketing Spend'],
    "R&D" : data['R&D Spend'],
    "ad" : data['Administration']
}
X = pd.DataFrame(X).values
y = data['Profit'].values

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = regressor.predict(X_test)
from sklearn.metrics import r2_score
print(f"accuracy score : {round(r2_score(y_test, y_pred)*100)}%")
# Out:
# accuracy score : 91%
